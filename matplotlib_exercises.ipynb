# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y = (x**2) - x +2

# %%
import matplotlib.pyplot as plt

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
x = range(-50, 51)
y = [ (n**2) - n + 2 for n in x]
plt.plot(x,y)
plt.annotate('The origin', xy = (0, 0), xytext = (30, 0), arrowprops = dict(facecolor = 'red'))
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
# y = √x
# y =x **3
# y=2**x
# y=1/(x+1)

# %%
# y = √x
import math
x = range (0, 12)
y = [math.sqrt(n) for n in x] 
plt.plot(x,y)

# %%
# y =x **3
x = range (0, 10)
y = [n ** 3 for n in x]
plt.plot(x,y)

# %%
# y=2**x
x = range (0, 8)
y = [2 ** n for n in x]
plt.plot(x,y)

# %%
# y= 1/(x+1)
x = range (0,11)
y = [1 / (n + 1) for n in x]
plt.plot(x,y)

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots

# %%
x = [x for x in range(0,11)]
# y = √x
y1 = [math.sqrt(n) for n in x] 
# y =x **3
y2 = [n ** 3 for n in x]
# y=2**x
y3 = [2 ** n for n in x]
# y= 1/(x+1)
y4 = [1 / (n + 1) for n in x]

# %%
# Define a figure
plt.figure(figsize = (10, 8))


plt.subplot(2,2,1)
plt.plot(x,y1, ls = '-', marker = '*', color = 'black')
plt.title('$y = √x$')
plt.grid(True, ls = '--', color = 'gray')

plt.subplot(2,2,2)
plt.plot(x,y2, ls = '-', marker = '+', color = 'black')
plt.title('$y = x **3$')
plt.grid(True, ls = '--', color = 'gray')

plt.subplot(2,2,3)
plt.plot(x,y3, ls = '-', marker = '*', color = 'black')
plt.title('$y = 2**x$')
plt.grid(True, ls = '--', color = 'gray')

plt.subplot(2,2,4)
plt.plot(x,y3, ls = '-', marker = '*', color = 'black')
plt.title('$y = 1/(x+1)$')
plt.grid(True, ls = '--', color = 'gray')

# add padding to avoid overlap of subplots
plt.tight_layout()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
# Define a figure
plt.figure(figsize = (10, 8))
plt.suptitle(' Combined Figures', fontsize = 16)

plt.subplot(2,2,1)
plt.plot(x,y1, ls = '-', marker = '*', color = 'blue')
plt.title('$y = √x$')
plt.grid(True, ls = '--', color = 'gray')




plt.subplot(2,2,2)
plt.plot(x,y2, ls = '-', marker = '+', color = 'green')
plt.title('$y = x **3$')
plt.grid(True, ls = '--', color = 'gray')


plt.subplot(2,2,3)
plt.plot(x,y3, ls = '-', marker = '*', color = 'orange')
plt.title('$y = 2**x$')
plt.grid(True, ls = '--', color = 'gray')


plt.subplot(2,2,4)
plt.plot(x,y3, ls = '-', marker = '*', color = 'm')
plt.title('$y = 1/(x+1)$')
plt.grid(True, ls = '--', color = 'gray')



# add padding to avoid overlap of subplots
plt.tight_layout()
